# %%
#!pip install optuna
#!pip -q install einops
#!pip install torch

# %%
import numpy as np
import torch
import optuna
from torch.utils.data import DataLoader
from set_data import load_real_weather, WeatherPairs, split_windows_train_val_test
from visualization import (plot_complete_data, 
                           plot_weatherpair_panel,
                           visualize_loss, plot_ctx_and_scenarios_panel)
from utils import *
from diffusion_model import DiffusionSchedule, TinyCondUNet1D
from diffusion_model_train import train_one_epoch, eval_epoch, EarlyStopping
from diffusion_model_generate import p_sample_loop
import error_metrics as em
np.set_printoptions(suppress=True)

VARS = 7
EPOCHS = 200
feature_names = ["T2M_MIN", "T2M_MAX", "PRECTOTCORR", "ALLSKY_SFC_SW_DWN", "RH2M", "WS2M", "Month"]

seed = 42
np.random.seed(seed)
torch.manual_seed(seed)
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device:", device)
# Out:
# device: cuda

# %%
X, columns = load_real_weather("../../data/data_20150630_to_20250630.csv", 
                      start_date="2015-06-30", end_date="2024-06-30")
print("Real data shape:", X.shape)  # (days, number of features)
CTX = 120
HORIZON = 60
dataset = WeatherPairs(X, ctx=CTX, horizon=HORIZON, stride=1)
train_ds, val_ds, test_ds = split_windows_train_val_test(dataset, test_frac=0.1, val_frac=0.1, train_frac=0.8)
mean, std = fit_standardizer(train_ds)
mean_t = torch.tensor(mean, device=device)
std_t = torch.tensor(std, device=device)
print("mean:", mean, "\nstd:", std)
# Out:
#            DATE    T2M_MIN    T2M_MAX  PRECTOTCORR  ALLSKY_SFC_SW_DWN   RH2M  \
# 2213 2021-07-21   7.510000  19.610000         0.00           8.780000  78.25
# 2772 2023-01-31  14.600000  34.880000         0.03          31.960000  40.67
# 1660 2020-01-15  11.160000  28.750000         0.01          34.470000  31.85
# 1656 2020-01-11  11.450000  36.220000         0.02          33.190000  38.80
# 3241 2024-05-14   2.648571  17.751429         0.18          12.504286  52.85
#
#           WS2M
# 2213  1.090000
# 2772  1.960000
# 1660  4.240000
# 1656  1.880000
# 3241  1.161429
# Real data shape: (3289, 7)
# mean: [ 8.390902  23.335821   1.2390072 18.926704  65.67608    1.5851314
#   6.467395 ]
# std: [ 3.80249     7.7259326   4.057628    9.836689   17.696545    0.56056035
#   3.471342  ]

# %%
def evaluate_crps_on_val(model, sched, val_ds, device, mean_t, std_t,
                         n_eval=64, n_scen=30):
    model.eval()
    idxs = np.random.choice(len(val_ds), size=min(n_eval, len(val_ds)), replace=False)
    crps_list = []
    for i in idxs:
        ctx, tgt = val_ds[i]
        ctx = ctx.unsqueeze(0).to(device)  # (1,CTX,D)
        y = tgt.detach().cpu().numpy()     # (H,D)

        scens = p_sample_loop(ctx, model, device, sched, HORIZON, VARS,
                              mean_t, std_t, n_scenarios=n_scen).detach().cpu().numpy()  # (S,H,D)

        # your function: returns (H,D) if average=False, then average
        crps_hd = em.crps_ensemble_snd(scens, y, average=False)
        crps_list.append(crps_hd.mean())
    return float(np.mean(crps_list))

def objective(trial):
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128, 256, 512])
    T = trial.suggest_categorical("T", [100, 250, 500])
    patience = trial.suggest_categorical("pat", [10, 25, 50])

    lr = trial.suggest_float("lr", 1e-5, 5e-4, log=True)
    wd = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
    momentum = trial.suggest_float("momentum", 0.85, 0.99)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

    sched = DiffusionSchedule(T=T)
    model = TinyCondUNet1D(in_vars=VARS, ctx_vars=VARS).to(device)


    opt = torch.optim.SGD(
        model.parameters(),
        lr=lr,
        momentum=momentum,
        weight_decay=wd,
        nesterov=True
    )


    early = EarlyStopping(patience=patience, min_delta=1e-4, mode="min")

    for e in range(1, 101):
        tr = train_one_epoch(opt, model, sched, device, train_loader, mean_t, std_t)
        va = eval_epoch(model, device, val_loader, sched, mean_t, std_t)

        if early.step(va, model, e):
            break

    early.restore_best(model)

    val_crps = evaluate_crps_on_val(
        model, sched, val_ds, device, mean_t, std_t,
        n_eval=64, n_scen=30
    )

    return val_crps


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

print("Best:", study.best_params, "CRPS:", study.best_value)
# Out:
# [I 2026-02-24 13:25:55,210] A new study created in memory with name: no-name-f4f76d40-37fb-439b-a4d1-25c90324ee2e
# [I 2026-02-24 13:27:19,556] Trial 0 finished with value: 4.460298538208008 and parameters: {'batch_size': 256, 'T': 100, 'pat': 10, 'lr': 7.60132471508592e-05, 'weight_decay': 1.1171608858709959e-06, 'momentum': 0.9473378530940288}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:28:35,025] Trial 1 finished with value: 4.795077800750732 and parameters: {'batch_size': 512, 'T': 100, 'pat': 50, 'lr': 5.023847080951839e-05, 'weight_decay': 8.313220143847372e-05, 'momentum': 0.8814262733170274}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:31:29,739] Trial 2 finished with value: 4.626410484313965 and parameters: {'batch_size': 64, 'T': 250, 'pat': 50, 'lr': 4.660796525542258e-05, 'weight_decay': 0.00010344967582664502, 'momentum': 0.8773705159313525}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:33:50,740] Trial 3 finished with value: 4.466556072235107 and parameters: {'batch_size': 64, 'T': 100, 'pat': 25, 'lr': 1.2369472147500546e-05, 'weight_decay': 0.0008741990488995684, 'momentum': 0.9655963036154478}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:35:12,409] Trial 4 finished with value: 4.577430725097656 and parameters: {'batch_size': 256, 'T': 100, 'pat': 10, 'lr': 4.896149032681161e-05, 'weight_decay': 3.05476715408853e-06, 'momentum': 0.940830821198725}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:36:27,466] Trial 5 finished with value: 4.894744873046875 and parameters: {'batch_size': 512, 'T': 100, 'pat': 10, 'lr': 1.2276213969035141e-05, 'weight_decay': 1.1332582615957072e-06, 'momentum': 0.9728247328738566}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:39:21,180] Trial 6 finished with value: 22.369407653808594 and parameters: {'batch_size': 512, 'T': 500, 'pat': 10, 'lr': 9.897993448474615e-05, 'weight_decay': 0.00015534703941371108, 'momentum': 0.8653197208741642}. Best is trial 0 with value: 4.460298538208008.
# [I 2026-02-24 13:42:39,650] Trial 7 finished with value: 4.317966938018799 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 6.919261045157006e-05, 'weight_decay': 9.184648722452676e-06, 'momentum': 0.957808283616733}. Best is trial 7 with value: 4.317966938018799.
# [I 2026-02-24 13:44:56,946] Trial 8 finished with value: 4.339127540588379 and parameters: {'batch_size': 128, 'T': 100, 'pat': 50, 'lr': 0.0002463740856800661, 'weight_decay': 1.0593230687085643e-05, 'momentum': 0.8917383191569659}. Best is trial 7 with value: 4.317966938018799.
# [I 2026-02-24 13:46:18,806] Trial 9 finished with value: 4.645786762237549 and parameters: {'batch_size': 256, 'T': 100, 'pat': 10, 'lr': 0.00012431148687780678, 'weight_decay': 1.5275535427661856e-06, 'momentum': 0.8517043158312438}. Best is trial 7 with value: 4.317966938018799.
# [I 2026-02-24 13:49:21,433] Trial 10 finished with value: 4.171419620513916 and parameters: {'batch_size': 32, 'T': 500, 'pat': 25, 'lr': 0.
. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:30:38,813] Trial 84 finished with value: 4.1630072593688965 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0004437416542211749, 'weight_decay': 0.00047068520084070104, 'momentum': 0.8837876648710496}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:34:05,022] Trial 85 finished with value: 4.080203056335449 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0004036632815657563, 'weight_decay': 0.0007103516559120115, 'momentum': 0.8661985524156726}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:37:32,023] Trial 86 finished with value: 4.413220405578613 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0002798807621921254, 'weight_decay': 0.0006847874806199729, 'momentum': 0.8684967774425875}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:41:23,426] Trial 87 finished with value: 4.277908802032471 and parameters: {'batch_size': 128, 'T': 500, 'pat': 50, 'lr': 0.00030731832494147385, 'weight_decay': 0.0003137324747270617, 'momentum': 0.8770230880514517}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:44:51,454] Trial 88 finished with value: 4.275177001953125 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 3.651540952668229e-05, 'weight_decay': 0.0007600083535442594, 'momentum': 0.8745683508007587}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:48:20,181] Trial 89 finished with value: 4.2339043617248535 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0004993611021598998, 'weight_decay': 0.0004521349203193568, 'momentum': 0.8785109360033645}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:49:56,587] Trial 90 finished with value: 4.3890886306762695 and parameters: {'batch_size': 32, 'T': 250, 'pat': 10, 'lr': 0.0003460786351252453, 'weight_decay': 0.0006246191398208589, 'momentum': 0.8645476044823225}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:53:19,025] Trial 91 finished with value: 4.139747619628906 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0003968264877374951, 'weight_decay': 0.00010761468193940816, 'momentum': 0.8562515218806345}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 17:56:48,166] Trial 92 finished with value: 4.171607971191406 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0004439543838072894, 'weight_decay': 0.0002119067446009687, 'momentum': 0.8697916239792024}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 18:00:18,871] Trial 93 finished with value: 4.553933143615723 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.000403241524893411, 'weight_decay': 0.0003248954120331582, 'momentum': 0.8606476407145596}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 18:03:09,774] Trial 94 finished with value: 4.379025459289551 and parameters: {'batch_size': 512, 'T': 500, 'pat': 50, 'lr': 0.0004549688854493895, 'weight_decay': 0.00015276234345482429, 'momentum': 0.8854186008428496}. Best is trial 64 with value: 3.9604897499084473.
# [I 2026-02-24 18:06:39,879] Trial 95 finished with value: 3.8483211994171143 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0003564393767954311, 'weight_decay': 0.0005550958975558031, 'momentum': 0.8656119134913925}. Best is trial 95 with value: 3.8483211994171143.
# [I 2026-02-24 18:10:08,811] Trial 96 finished with value: 4.3239593505859375 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0003418391176421257, 'weight_decay': 0.0008455581102697916, 'momentum': 0.8938603019994799}. Best is trial 95 with value: 3.8483211994171143.
# [I 2026-02-24 18:12:04,098] Trial 97 finished with value: 4.609147071838379 and parameters: {'batch_size': 32, 'T': 100, 'pat': 50, 'lr': 0.00037354068111942443, 'weight_decay': 0.0005224134201584234, 'momentum': 0.890518054902981}. Best is trial 95 with value: 3.8483211994171143.
# [I 2026-02-24 18:15:31,654] Trial 98 finished with value: 4.366665840148926 and parameters: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.00030410677745677594, 'weight_decay': 0.0002618019351467538, 'momentum': 0.8663039052898599}. Best is trial 95 with value: 3.8483211994171143.
# [I 2026-02-24 18:18:25,208] Trial 99 finished with value: 4.396825790405273 and parameters: {'batch_size': 64, 'T': 250, 'pat': 50, 'lr': 0.0002669745667233159, 'weight_decay': 0.00037958788623073254, 'momentum': 0.8823271462543115}. Best is trial 95 with value: 3.8483211994171143.
# Best: {'batch_size': 32, 'T': 500, 'pat': 50, 'lr': 0.0003564393767954311, 'weight_decay': 0.0005550958975558031, 'momentum': 0.8656119134913925} CRPS: 3.8483211994171143
